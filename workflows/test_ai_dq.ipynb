# %% [markdown]
# ### **Bronze Layer**

# %%
from pyspark.sql import Row

data = [
    Row(product_id=1, product_name="iPhone 16 Pro Black 256 GB"),
    Row(product_id=2, product_name="Apple iPhone16 Pro 256GB Black"),
    Row(product_id=3, product_name="Apple iPhone 16 Pro Black"),
    Row(product_id=4, product_name="Samsung Galaxy S25 Ultra")
]

bronze_df = spark.createDataFrame(data)

bronze_df.write.mode("overwrite").saveAsTable("ai_lab_demo.bronze.products")
