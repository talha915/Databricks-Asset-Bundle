# %%
import sys

PROJECT_ROOT = "/Workspace/Users/tz915426@gmail.com/Databricks-Asset-Bundle/pipeline"

if PROJECT_ROOT not in sys.path:
    sys.path.append(PROJECT_ROOT)

# %%
dbutils.widgets.text(
    "task_name",
    ""
)


task_name=dbutils.widgets.get(
    "task_name"
)

# %%
from framework.run_task import execute_task

# %%
execute_task(
    "bronze",
    task_name
)

# %%
VOLUME_PATH = "/Volumes/ai_lab_demo/dataset/ai_lab_demo_src"

employees_src_a = f"{VOLUME_PATH}/employees/sourceC"

# %%
df = spark.read \
    .format("xml") \
    .option("rowTag", "record") \
    .option("inferSchema", "true") \
    .load(employees_src_a)

# %%
df.display()
