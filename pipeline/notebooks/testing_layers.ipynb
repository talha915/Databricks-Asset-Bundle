# %%
import sys, os
import pytest 
PROJECT_ROOT = "/Workspace/Users/tz915426@gmail.com/Databricks-Asset-Bundle/pipeline"

if PROJECT_ROOT not in sys.path:
    sys.path.append(PROJECT_ROOT)

# %%
dbutils.widgets.text(
    "task_name",
    ""
)


task_name=dbutils.widgets.get(
    "task_name"
)

# %%
import pytest

pytest.main([
    "-v",
    "-p", "no:cacheprovider",
    "--assert=plain",
    f"../tests/{task_name}"
])

# %%
# from tests.test_bronze import TestBronze

# test = TestBronze(spark)

# test.test_table_exists()
# test.test_bronze_table_has_data()
# test.test_bronze_required_columns()
