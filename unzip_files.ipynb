# %%
import subprocess

# %%
# %sh
unzip /Volumes/ai_lab_demo/source/source_volume/source_crm.zip -d /Volumes/ai_lab_demo/source/source_volume/

# %%
# %sh
unzip /Volumes/ai_lab_demo/source/source_volume/source_erp.zip -d /Volumes/ai_lab_demo/source/source_volume/
