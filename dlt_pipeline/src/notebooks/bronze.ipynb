# %%
from src.pipelines.bronze.bronze_crm_cust_info import CRMBronze
from src.pipelines.bronze.bronze_erp_cust import ERPBronze
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from src.pipelines.bronze.bronze_crm_cust_info import CRMBronze
#       2 from src.pipelines.bronze.bronze_erp_cust import ERPBronze
#
# ModuleNotFoundError: No module named 'src'

# %%
CRMBronze().register()
ERPBronze().register()
