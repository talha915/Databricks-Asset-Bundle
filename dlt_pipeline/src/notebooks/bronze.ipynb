# %%
import sys
import os

# bundle root path (correct one)
BUNDLE_ROOT = "/Workspace/Users/tz915426@gmail.com/.bundle/dlt_pipeline/dev/files"

if BUNDLE_ROOT not in sys.path:
    sys.path.insert(0, BUNDLE_ROOT)

# %%
from src.pipelines.bronze.bronze_crm import CRMBronze
from src.pipelines.bronze.bronze_erp import ERPBronze

# %%
CRMBronze().register()
ERPBronze().register()
